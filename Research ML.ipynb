# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import sklearn

# %matplotlib inline

df = pd.read_csv("C:/Users/shahh/OneDrive/Desktop/Research Paper - KS/Final CSV/April/final_data.csv")
df
# Out:
#          Sr. 0  Temperature            File Name  Series  Parallel  Shading  \
# 0            1           27  10X1_0_Shadding.txt      10         1        0
# 1            2           27  10X1_0_Shadding.txt      10         1        0
# 2            3           27  10X1_0_Shadding.txt      10         1        0
# 3            4           27  10X1_0_Shadding.txt      10         1        0
# 4            5           27  10X1_0_Shadding.txt      10         1        0
# ...        ...          ...                  ...     ...       ...      ...
# 101575  101576           50        5X2_9shadding       5         2        9
# 101576  101577           50        5X2_9shadding       5         2        9
# 101577  101578           50        5X2_9shadding       5         2        9
# 101578  101579           50        5X2_9shadding       5         2        9
# 101579  101580           50        5X2_9shadding       5         2        9
#
#         Number of cells  Voltage (V)  Current (I)     I/V  Solar Panel  \
# 0                    10         0.01         4.34  434.24            1
# 1                    10         0.02         4.34  217.12            1
# 2                    10         0.03         4.34  144.75            1
# 3                    10         0.04         4.34  108.56            1
# 4                    10         0.05         4.34   86.85            1
# ...                 ...          ...          ...     ...          ...
# 101575               10         2.96       -45.69  -15.43        10767
# 101576               10         2.97       -47.61  -16.03        10767
# 101577               10         2.98       -49.56  -16.63        10767
# 101578               10         2.99       -51.56  -17.24        10767
# 101579               10         3.00       -53.58  -17.86        10767
#
#         Cell 0  Shade Percentage  IsShade
# 0            1               0.0        0
# 1            2               0.0        0
# 2            3               0.0        0
# 3            4               0.0        0
# 4            5               0.0        0
# ...        ...               ...      ...
# 101575       6              90.0        1
# 101576       7              90.0        1
# 101577       8              90.0        1
# 101578       9              90.0        1
# 101579      10              90.0        0
#
# [101580 rows x 14 columns]

# %%
df = df.drop(columns=['File Name'])
df
# Out:
#          Sr. 0  Temperature  Series  Parallel  Shading  Number of cells  \
# 0            1           27      10         1        0               10
# 1            2           27      10         1        0               10
# 2            3           27      10         1        0               10
# 3            4           27      10         1        0               10
# 4            5           27      10         1        0               10
# ...        ...          ...     ...       ...      ...              ...
# 101575  101576           50       5         2        9               10
# 101576  101577           50       5         2        9               10
# 101577  101578           50       5         2        9               10
# 101578  101579           50       5         2        9               10
# 101579  101580           50       5         2        9               10
#
#         Voltage (V)  Current (I)     I/V  Solar Panel  Cell 0  \
# 0              0.01         4.34  434.24            1       1
# 1              0.02         4.34  217.12            1       2
# 2              0.03         4.34  144.75            1       3
# 3              0.04         4.34  108.56            1       4
# 4              0.05         4.34   86.85            1       5
# ...             ...          ...     ...          ...     ...
# 101575         2.96       -45.69  -15.43        10767       6
# 101576         2.97       -47.61  -16.03        10767       7
# 101577         2.98       -49.56  -16.63        10767       8
# 101578         2.99       -51.56  -17.24        10767       9
# 101579         3.00       -53.58  -17.86        10767      10
#
#         Shade Percentage  IsShade
# 0                    0.0        0
# 1                    0.0        0
# 2                    0.0        0
# 3                    0.0        0
# 4                    0.0        0
# ...                  ...      ...
# 101575              90.0        1
# 101576              90.0        1
# 101577              90.0        1
# 101578              90.0        1
# 101579              90.0        0
#
# [101580 rows x 13 columns]

# %%
df.describe()
# Out:
#                Sr. 0    Temperature         Series       Parallel  \
# count  101580.000000  101580.000000  101580.000000  101580.000000
# mean    50790.500000      37.816893       6.026580       2.387478
# std     29323.764509       8.067579       3.338546       1.940320
# min         1.000000      27.000000       1.000000       1.000000
# 25%     25395.750000      30.000000       3.000000       1.000000
# 50%     50790.500000      35.000000       5.000000       2.000000
# 75%     76185.250000      45.000000      10.000000       3.000000
# max    101580.000000      50.000000      10.000000      10.000000
#
#              Shading  Number of cells    Voltage (V)    Current (I)  \
# count  101580.000000    101580.000000  101580.000000  101580.000000
# mean        4.751920         9.508565       1.812974       4.220582
# std         3.052597         0.796899       1.557915      12.070529
# min         0.000000         8.000000       0.010000    -221.730000
# 25%         2.000000         9.000000       0.590000       2.180000
# 50%         5.000000        10.000000       1.320000       4.340000
# 75%         7.000000        10.000000       2.580000       6.520000
# max        10.000000        10.000000       6.000000      43.420000
#
#                  I/V    Solar Panel         Cell 0  Shade Percentage  \
# count  101580.000000  101580.000000  101580.000000     101580.000000
# mean       25.149340    5369.984347       5.254282         49.976373
# std       130.060357    3109.685957       2.768180         31.755699
# min      -369.540000       1.000000       1.000000          0.000000
# 25%         0.710000    2671.000000       3.000000         20.000000
# 50%         3.170000    5385.500000       5.000000         50.000000
# 75%        12.770000    8053.000000       8.000000         80.000000
# max      4342.380000   10767.000000      10.000000        100.000000
#
#              IsShade
# count  101580.000000
# mean        0.499764
# std         0.500002
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(11,8))
sns.heatmap(df.corr(),cmap="BrBG",annot=True)

# %% [markdown]
# We can observe that below columns are having strong correlation between each other
# 1. Solar Panel and Temperature (0.98)
# 2. Shading and Shade Percentage (0.99)
# 3. Series and Parallel (-0.75)
# 4. Series and Voltage (0.64)
# 5. Series and Number of Cells (0.51)
# 6. Parallel and Voltage (-0.48)
# 7. Parallel and Current (0.34)
# 8. Parallel and I/V (0.34)
# 9. Voltage and Number of Cells (0.33)
# 10. Current and I/V (0.32)
# 11. Series and Current (-0.26)
# 12. Series and I/V (-0.21)

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#          Sr. 0  Temperature  Series  Parallel  Shading  Number of cells  \
# 0        98352           50       5         2        0               10
# 1        49678           35       5         2        5               10
# 2        56963           40      10         1        9               10
# 3       100748           50       5         2        7               10
# 4       101546           50       5         2        9               10
# ...        ...          ...     ...       ...      ...              ...
# 101575   32043           30       5         2        3               10
# 101576    4953           27      10         1        7               10
# 101577   51768           40      10         1       10               10
# 101578   28747           30       4         2        1                8
# 101579   84459           45       5         2        9               10
#
#         Voltage (V)  Current (I)    I/V  Solar Panel  Cell 0  \
# 0              0.72         8.68  12.06        10445       2
# 1              2.98       -23.79  -7.98         5274       8
# 2              0.83         2.17   2.62         6003       3
# 3              0.68         4.35   6.40        10684       8
# 4              2.66        -7.00  -2.63        10764       6
# ...             ...          ...    ...          ...     ...
# 101575         1.83         6.52   3.56         3410       3
# 101576         1.53         2.18   1.42          496       3
# 101577         2.88         2.17   0.75         5483       8
# 101578         0.07         6.52  93.15         3032       7
# 101579         0.39         4.34  11.14         8954       9
#
#         Shade Percentage  IsShade
# 0                    0.0        0
# 1                   50.0        0
# 2                   90.0        1
# 3                   70.0        0
# 4                   90.0        1
# ...                  ...      ...
# 101575              30.0        1
# 101576              70.0        1
# 101577             100.0        1
# 101578              12.5        0
# 101579              90.0        1
#
# [101580 rows x 13 columns]

# %%
sns.pairplot(df)

# %%
matplotlib.rcParams['font.size'] = 20
sns.pairplot(df, hue = 'Temperature');

# %%
# Labels are the values we want to predict
labels = np.array(df['IsShade'])
# labels
# Remove the labels from the features
# # axis 1 refers to the columns
features= df.drop('IsShade', axis = 1)
# # Saving feature names for later use
feature_list = list(features.columns)
# # Convert to numpy array
features = np.array(features)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.34, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (67042, 12)
# Training Labels Shape: (67042,)
# Testing Features Shape: (34538, 12)
# Testing Labels Shape: (34538,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
predictions
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# errors
# Print out the mean absolute error (mae)
# print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Mean Absolute Error: 3.83 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
