# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import sklearn
from sklearn.utils import shuffle
# from sklearn.model_selection import train_test_split

# %matplotlib inline

df = pd.read_csv("C:/Users/shahh/OneDrive/Desktop/Research Paper - KS/Final CSV/April/final_data.csv")
# df = df.drop(columns=['File Name','Number of cells','Cell Number'])
df = shuffle(df)
df

# %%
df = df.drop(columns=['File Name'])
df
# Out:
#        Sr. 0  Temperature  Series  Parallel  Shading  Number of cells  \
# 87727  87728           50      10         1        4               10
# 17419  17420           30      10         1        0               10
# 65958  65959           40       5         2        3               10
# 81481  81482           45       5         2        0               10
# 95075  95076           50       3         3        4                9
# ...      ...          ...     ...       ...      ...              ...
# 14713  14714           27       5         2        2               10
# 70129  70130           45      10         1        2               10
# 60712  60713           40       3         3        0                9
# 68151  68152           45      10         1        0               10
# 36841  36842           35      10         1        3               10
#
#        Voltage (V)  Current (I)    I/V  Solar Panel  Cell Number  \
# 87727         0.08         2.18  27.30         9281            8
# 17419         5.00         3.87   0.77         1843           10
# 65958         2.59         3.20   1.24         7003            9
# 81481         0.62         8.68  14.01         8657            2
# 95075         0.36         8.69  24.14        10051            9
# ...            ...          ...    ...          ...          ...
# 14713         1.94         6.52   3.36         1573            4
# 70129         5.30        -0.39  -0.07         7420           10
# 60712         1.73       -23.56 -13.62         6407            2
# 68151         3.52         4.34   1.23         7223            2
# 36841         4.82         2.18   0.45         3890            2
#
#        Shade Percentage  IsShade
# 87727             40.00        0
# 17419              0.00        0
# 65958             30.00        0
# 81481              0.00        0
# 95075             44.44        0
# ...                 ...      ...
# 14713             20.00        0
# 70129             20.00        0
# 60712              0.00        0
# 68151              0.00        0
# 36841             30.00        1
#
# [101580 rows x 13 columns]

# %%
X = df.drop('IsShade', axis=1)
y = df['IsShade']

# %%
from sklearn.model_selection import train_test_split
# implementing train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.34, random_state=44)

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
# random forest model creation
rfc = RandomForestClassifier(n_estimators=200, random_state=39, max_depth=4)
rfc.fit(X_train,y_train)
# predictions
rfc_predict = rfc.predict(X_test)

# %%
print('Train set')
train_pred = rfc.predict_proba(X_train)
print('Random Forests roc-auc: {}'.format(roc_auc_score(y_train, train_pred[:,1])))
print('Test set')
test_pred = rfc.predict_proba(X_test)
print('Random Forests roc-auc: {}'.format(roc_auc_score(y_test, test_pred[:,1])))
# Out:
# Train set
# Random Forests roc-auc: 0.988313379077237
# Test set
# Random Forests roc-auc: 0.9890708069588219

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix

rfc_cv_score = cross_val_score(rfc, X, y, cv=10, scoring='roc_auc')

# %%
print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, rfc_predict))
print('\n')
print("=== Classification Report ===")
print(classification_report(y_test, rfc_predict))
print('\n')
print("=== All AUC Scores ===")
print(rfc_cv_score)
print('\n')
print("=== Mean AUC Score ===")
print("Mean AUC Score - Random Forest: ", rfc_cv_score.mean())
# Out:
# === Confusion Matrix ===
# [[16144  1011]
#  [ 1169 16214]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94     17155
#            1       0.94      0.93      0.94     17383
#
#     accuracy                           0.94     34538
#    macro avg       0.94      0.94      0.94     34538
# weighted avg       0.94      0.94      0.94     34538
#
#
#
# === All AUC Scores ===
# [0.98885658 0.98849702 0.98904323 0.99040103 0.98941912 0.98655893
#  0.98776569 0.98801729 0.98802531 0.98794835]
#
#
# === Mean AUC Score ===
# Mean AUC Score - Random Forest:  0.9884532546850198

# %%
from sklearn.metrics import accuracy_score

print("Train Accuracy :: ", accuracy_score(y_train, rfc.predict(X_train)))
print("Test Accuracy  :: ", accuracy_score(y_test, rfc_predict))
# Out:
# Train Accuracy ::  0.933549118463053
# Test Accuracy  ::  0.9368811164514448

# %%
from sklearn.model_selection import KFold
scores_rf = []
kfold = KFold(n_splits=10)
print("Cross-validation scores:\n{}".format(
      scores_rf.append(cross_val_score(rfc, X, y, cv=kfold))))
print("Cross-validation scores:\n{}".format(
      cross_val_score(rfc, X, y, cv=kfold)))
print(np.mean(scores_rf))
# Out:
# Cross-validation scores:
# None
# Cross-validation scores:
# [0.93827525 0.9436897  0.94024414 0.94004725 0.9474306  0.93581414
#  0.94063792 0.9328608  0.94595393 0.93827525]
# 0.9403228982083087

# %%
from sklearn.model_selection import StratifiedKFold
scores_rf = []
skfold = StratifiedKFold(n_splits=10)
print("Cross-validation scores:\n{}".format(
      scores_rf.append(cross_val_score(rfc, X, y, cv=kfold))))
print("Cross-validation scores:\n{}".format(
      cross_val_score(rfc, X, y, cv=skfold)))
print("10 fold (StratiedFold): ",np.mean(scores_rf))
