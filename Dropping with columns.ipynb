# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import sklearn
from sklearn.utils import shuffle
# from sklearn.model_selection import train_test_split

# %matplotlib inline

df = pd.read_csv("C:/Users/shahh/OneDrive/Desktop/Research Paper - KS/Final CSV/April/final_data.csv")
df = df.drop(columns=['File Name','Number of cells','Cell Number'])
df = shuffle(df)
df
# Out:
#          Sr. 0  Temperature  Series  Parallel  Shading  Voltage (V)  \
# 56295    56296           40      10         1        8         0.16
# 28593    28594           30       4         2        0         0.94
# 13843    13844           27       5         2        0         2.24
# 68401    68402           45      10         1       10         0.02
# 100055  100056           50       5         2        4         2.76
# ...        ...          ...     ...       ...      ...          ...
# 23125    23126           30      10         1        9         2.06
# 35924    35925           35      10         1        2         1.65
# 10890    10891           27       3         3        6         1.51
# 49963    49964           35       5         2        6         2.84
# 19277    19278           30      10         1        2         5.58
#
#         Current (I)     I/V  Solar Panel  Shade Percentage  IsShade
# 56295          2.17   13.58         5936             80.00        1
# 28593          8.68    9.24         3013              0.00        0
# 13843          8.59    3.84         1486              0.00        0
# 68401          2.17  108.56         7248            100.00        1
# 100055       -13.90   -5.04        10615             40.00        0
# ...             ...     ...          ...               ...      ...
# 23125          2.17    1.06         2414             90.00        1
# 35924          2.19    1.33         3798             20.00        0
# 10890          7.50    4.97         1130             66.67        0
# 49963         -7.99   -2.81         5303             60.00        1
# 19277          0.01    0.00         2029             20.00        0
#
# [101580 rows x 11 columns]

# %%
X = df.drop('IsShade', axis=1)
y = df['IsShade']

# %%
from sklearn.model_selection import train_test_split
# implementing train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.34, random_state=66)

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
# random forest model creation
rfc = RandomForestClassifier(n_estimators=200, random_state=39, max_depth=4)
rfc.fit(X_train,y_train)
# predictions
rfc_predict = rfc.predict(X_test)
rfc_predict

# %%
print('Train set')
train_pred = rfc.predict_proba(X_train)
print('Random Forests roc-auc: {}'.format(roc_auc_score(y_train, train_pred[:,1])))
print('Test set')
test_pred = rfc.predict_proba(X_test)
print('Random Forests roc-auc: {}'.format(roc_auc_score(y_test, test_pred[:,1])))
# Out:
# Train set
# Random Forests roc-auc: 0.8693367867444893
# Test set
# Random Forests roc-auc: 0.8668399305063246

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
rfc_cv_score = cross_val_score(rfc, X, y, cv=10, scoring='roc_auc')

# %%
print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, rfc_predict))
print('\n')
print("=== Classification Report ===")
print(classification_report(y_test, rfc_predict))
print('\n')
print("=== All AUC Scores ===")
print(rfc_cv_score)
print('\n')
print("=== Mean AUC Score ===")
print("Mean AUC Score - Decision Trees: ", rfc_cv_score.mean())
# Out:
# === Confusion Matrix ===
# [[13006  4251]
#  [ 3547 13734]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77     17257
#            1       0.76      0.79      0.78     17281
#
#     accuracy                           0.77     34538
#    macro avg       0.77      0.77      0.77     34538
# weighted avg       0.77      0.77      0.77     34538
#
#
#
# === All AUC Scores ===
# [0.87302463 0.86321774 0.86826074 0.8632011  0.86923686 0.86308877
#  0.86542428 0.86925985 0.87319029 0.87149391]
#
#
# === Mean AUC Score ===
# Mean AUC Score - Decision Trees:  0.8679398167115219

# %%
from sklearn.metrics import accuracy_score

print("Train Accuracy :: ", accuracy_score(y_train, rfc.predict(X_train)))
print("Test Accuracy  :: ", accuracy_score(y_test, rfc_predict))
# Out:
# Train Accuracy ::  0.7780794129053429
# Test Accuracy  ::  0.7742197000405351
